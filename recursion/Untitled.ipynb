# %%
final=[]
def minimum_coins(tar,coins,s=[]):
     
     global final
     if tar==0:
          final.append(s)
          #print(s)
          return 1
     if tar<0:
          s=[]
          return 0
     

     x=[]
     for i in coins:
          
          x.append(minimum_coins(tar-i,coins,s+[str(i)]))
     
     
def calculate(tar, coins):
     global final
     final=[]
     minimum_coins(tar, coins)
     #print(final)
     x=final[0]
     for i in range(1,len(final)):
          if len(final[i])<len(x):
               x=final[i]
     return len(x)

# %%
calculate(74,[1,5,10,25])
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 3296, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-21-46233b2ddab9>", line 1, in <module>
#     calculate(74,[1,5,10,25])
#   File "<ipython-input-18-30620f42f87d>", line 23, in calculate
#     minimum_coins(tar, coins)
#   File "<ipython-input-18-30620f42f87d>", line 17, in minimum_coins
#     x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#   File "<ipython-input-18-30620f42f87d>", line 17, in minimum_coins
#     x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#   File "<ipython-input-18-30620f42f87d>", line 17, in minimum_coins
#     x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#   [Previous line repeated 34 more times]
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 2033, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'MemoryError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 3220, in run_ast_nodes
#     if (yield from self.run_code(code, result)):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 3313, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 2036, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 1379, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 1282, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 1133, in structured_traceback
#     tb_offset)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 1078, in format_exception_as_a_whole
#     frames = self.format_records(records, last_unique, recursion_repeat)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 825, in format_records
#     frames.append(self.format_record(*r))
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\ultratb.py", line 1008, in format_record
#     _line_format)))
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 2874, in _run_cell
#     return runner(coro)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\async_helpers.py", line 67, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 3049, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 3239, in run_ast_nodes
#     self.showtraceback()
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1133, in run
#     value = future.result()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 326, in wrapper
#     yielded = next(result)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 2848, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\IPython\core\interactiveshell.py", line 2879, in _run_cell
#     self.showtraceback(running_compiled_code=True)
# MemoryError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\logging\__init__.py", line 997, in emit
#     stream.write(self.terminator)
# OSError: [WinError 233] No process is on the other end of the pipe
# Call stack:
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\platform\asyncio.py", line 132, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\asyncio\base_events.py", line 427, in run_forever
#     self._run_once()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\asyncio\base_events.py", line 1440, in _run_once
#     handle._run()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\asyncio\events.py", line 145, in _run
#     self._callback(*self._args)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\stack_context.py", line 300, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1233, in inner
#     self.run()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1147, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 346, in wrapper
#     runner = Runner(result, future, yielded)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1080, in __init__
#     self.run()
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\tornado\gen.py", line 1141, in run
#     yielded = self.gen.throw(*exc_info)
#   File "C:\Users\msais\Anaconda3\envs\gg\lib\site-packages\ipykernel\kernelbase.py", line 274, in dispatch_shell
#     self.log.error("Exception in message handler:", exc_info=True)
# Message: 'Exception in message handler:'
# Arguments: ()

# %%
from nose.tools import assert_equal

class TestCoins(object):
    
    def check(self,solution):
        coins = [1,5,10,25]
        assert_equal(solution(45,coins),3)
        assert_equal(solution(23,coins),5)
        assert_equal(solution(74,coins),8)

        print ('Passed all tests.')
        
# Run Test

test = TestCoins()
test.check(calculate)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-792544aefa74> in <module>
#      14
#      15 test = TestCoins()
# ---> 16 test.check(calculate)
#
# <ipython-input-20-792544aefa74> in check(self, solution)
#       7         assert_equal(solution(45,coins),3)
#       8         assert_equal(solution(23,coins),5)
# ----> 9         assert_equal(solution(74,coins),8)
#      10
#      11         print ('Passed all tests.')
#
# <ipython-input-18-30620f42f87d> in calculate(tar, coins)
#      21      global final
#      22      final=[]
# ---> 23      minimum_coins(tar, coins)
#      24      #print(final)
#      25      x=final[0]
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# <ipython-input-18-30620f42f87d> in minimum_coins(tar, coins, s)
#      15      for i in coins:
#      16
# ---> 17           x.append(minimum_coins(tar-i,coins,s+[str(i)]))
#      18
#      19
#
# KeyboardInterrupt:
